# %% [markdown]
# # HTML 기본 크롤링

# %% [markdown]
# # requests객체
# - HTTP 요청을 보내는 모듈(웹사이트 접속)

# %%
import requests
URL = 'https://scrapying-study.firebaseapp.com/01/'

response = requests.get(URL)

print(response.status_code)
print()
print(response.text)
# Out:
# 200
#
# <!DOCTYPE html>
# <html>
# <head>
# <title>크롤링 연습사이트 01</title>
# </head>
# <body>
# <h1>저의 첫 웹사이트 오신것을 환영합니다.</h1>
# <h1 title="welcome">인사이트캠퍼스.</h1>
# <h2>이곳은 크롤링 연습을 위한 웹사이트입니다.</h2>
# <table border="1">
#     <thead>
#       <tr>
#       	<th class="tablehead">이름</th>
#         <th class="tablehead">나이</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#           <td>이몽룡</td>
#           <td>34</td>
#       </tr>
#       <tr>
#           <td>홍길동</td>
#           <td>23</td>
#       </tr>
#      </tbody>
# </table>
# <p id="hello">
#     이탈리아 요리의 시작은 기원전 4세기로 거슬러 올라갈 수 있다. 대항해시대를 거치면서 아메리카 대륙에서 감자·토마토·후추·옥수수 등이 유입되어 그 종류와 풍미가 다양해졌고 현대에 이르러서는 피자와 파스타 등 많은 이탈리아 요리가 널리 퍼지게 되었다.
# </p>
# <p id="cook">
#     전통적인 요리법이나 양식은 상당한 차이가 있지만, 이탈리아 요리는 다른 국가의 요리 문화에서 다양한 영감을 줄 만큼 다양하고 혁신적인 것으로 평가되고 있다. 각 지방마다 고유의 특색이 있어 그 양식도 다양하지만 크게 북부와 남부로 나눌 수 있다. 다른 나라와 국경을 맞대고 있던 북부 지방은 산업화되어 경제적으로 풍족하고 농업이 발달해 쌀이 풍부해 유제품이 다양한 반면 경제적으로 침체되었던 남부 지방은 올리브와 토마토, 모차렐라 치즈가 유명하고 특별히 해산물을 활용한 요리가 많다. 식재료와 치즈 등의 차이는 파스타의 종류와 소스와 수프 등도 다름을 의미한다.
# </p>
# <a href="01.html">1페이지 바로가기</a>
# <a href="02.html">2페이지 바로가기</a>
# <a href="03.html">3페이지 바로가기</a>
# <a href="04.html">4페이지 바로가기</a>
# </body>
# </html>

# %% [markdown]
# ### header 설정하기
# ![header](./image/크롤링/header3.png)
# ![header](./image/크롤링/header.png)

# %%
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36'}
response = requests.get("https://store.musinsa.com/app/goods/1755609",headers=headers) # 위에서 사용한 URL과 같다.

print(response.status_code) # [HTTP 상태코드](https://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C) 반환 -> 200 (정상 작동)
print(response.text) # 페이지 html 코드 반환.
# Out:
# 200
# <!DOCTYPE html>
# <html lang="ko">
# <head>
#
# <!-- Google Tag Manager -->
# <script>
# var selfCertEnabled = "" || "Y";
# var THIS_PAGE_GF = 'A'; // 전역필터 상태값 caching page reload 필요 체크용
# var dataLayer = window.dataLayer || [];
# window.addEventListener("DOMContentLoaded", function() {
#
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-TXDSFSF');
# }, false);
# </script>
# <!-- End Google Tag Manager -->
#
# <meta charset="UTF-8">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <link rel="shortcut icon" href="/favicon.ico?20200213" type="image/x-icon">
# <meta name="description" content="제품분류 : 상의 > 기타 상의 브랜드 : 지프(JEEP) 제품번호 : JM5TSU838MG 제품 : Half  Zip-Up M-Logo Sweat  (JM5TSU838MG) - 48,300 원산지 : 대한민국 " />
#
#
# <!-- 페이스북 오픈 그래프 메타태그  -->
# <meta id="fbAddId" property="fb:app_id" content="648837775133366" />
# <meta id="fbOgType" property="og:type" content="website" />
# <meta id="fbOgTitle" property="og:title" content="지프(JEEP) Half  Zip-Up M-Logo Sweat  (JM5TSU838MG) - 48,300 | 무신사 스토어" />
# <meta id="fbOgImage" property="og:image" content="https://image.msscdn.net/images/goods_img/20210120/1755609/1755609_1_500.jpg" />
# <meta id="fbOgDescription" property="og:description" content="제품분류 : 상의 > 기타 상의 브랜드 : 지프(JEEP) 제품번호 : JM5TSU838MG 제품 : Half  Zip-Up M-Logo Sweat  (JM5TSU838MG) - 48,300 원산지 : 대한민국 " />
# <meta id="fbOgUrl" property="og:url" content="https://store.musinsa.com/app/goods/1755609?_gf=A">
# <!--// 페이스북 오픈 그래프 메타태그 -->
#
# <title>지프(JEEP) Half  Zip-Up M-Logo Sweat  (JM5TSU838MG) - 48,300 | 무신사 스토어</title>
#
# <link rel="stylesheet" type="text/css" href="//static.msscdn.net/static/common/1.2.0/pc.css" />
# <link rel="stylesheet" type="text/css" href="//static.msscdn.net/ui/build/pc/css/common.css?202105201000">
#
#     <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/magazine_common.css?202102031711" />
#     <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/store_common.css?202012081147" />
#     <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/layout.min.css?202104131714">
# <link rel="stylesheet" href="//image.msscdn.net/ui/musinsa/resources/common/css/icon.min.css?202101051200">
# <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/guide.min.css?202104211624">
# <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/style.min.css?202105201400">    <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/sub.css?202104131025" />
#     <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/media_query.css?202010301640" />
#     <!--<link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/font.css?20170221" />-->
#     <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/new.css?202011200920" />
#
# <!-- Swiper -->
# <link rel="stylesheet" type="text/css" href="//static.msscdn.net/swiper/swiper.min.css" />
# <script src="//static.msscdn.net/swiper/swiper.min.js?20200316"></script>
# <!-- Polyfill -->
#
# <script>
#     if (/MSIE \d|Trident.*rv:/.test(navigator.userAgent)) {
#         (function (w, d, s) {
#             var f = d.getElementsByTagName(s)[0];
#             var j = d.createElement(s);
#             j.async=true;
#             j.src= '//static.msscdn.net/skin/musinsa/js/polyfill.min.js?features=Array.from,Promise,fetch&flags=always';
#             f.parentNode.insertBefore(j, f);
#         })(window, document, 'script');
#     }
# </script>
#
# <!-- 스토어, 매거진 공통 스크립트 -->
# <script type="text/javascript" src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery-1.11.1.min.js?20160201"></script>
# <script type="text/javascript" src="//static.msscdn.net/mfile_outsrc/js/common/base.js?20160201"></script>
# <script type="text/javascript" src="//static.msscdn.net/mfile_outsrc/js/common/common.js?202105041500"></script>
# <script type="text/javascript" src="//static.msscdn.net/mfile_outsrc/js/vendor/jquery.easing.js?20160201"></script>
# <!--// 스토어, 매거진 공통 스크립트 -->
#
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/mini_cart.js?202105171800"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/common.js?202105211252"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/jquery.cycle.all.js?20160202"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/m_js/jquery-ui.min.js?20160202"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/jslib.js?20200601"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/jquery.bxslider.js?20180503"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/suggestions.js?202011170900"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/search_form.js?202101121530"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/clipboard.min.js?20170406"></script>
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/ui.js?20200528"></script>
# <script src="//static.msscdn.net/static/common/1.2.0/chunk-vendors.js"></script>
#
# <script src="//static.msscdn.net/skin/js/app/app.js?d3e74199da29a4258fe1"></script>
#
#     <!--jqModal-->
#     <link rel="stylesheet" type="text/css" href="//static.msscdn.net/skin/musinsa/css/jqModal.css?20160119" />
#     <script src="//static.msscdn.net/skin/musinsa/js/jqModal.min.js?20160511" type="text/javascript"></script>
#     <!--//jqModal-->
#
# <!-- 매거진 관심브랜드 관련 스크립트 -->
# <script type="text/javascript" src="https://magazine.musinsa.com/layouts/community/js/ex.script.js"></script>
# <!--// 매거진 관심브랜드 관련 스크립트 -->
#
# <!-- 유사 이미지 상품 검색 -->
# <link type="text/css" rel="stylesheet" href="//static.msscdn.net/skin/musinsa/css/image_search.css?20181203_02" />
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/image_search.js?20201207"></script>
# <!-- //유사 이미지 상품 검색 -->
#
#
# <script type="text/javascript">
#     if (!String.prototype.startsWith) {
#         String.prototype.startsWith = function(search, pos) {
#             return this.substr(!pos || pos < 0 ? 0 : +pos, search.length) === search;
#         };
#     }
#
#     var pathname = location.pathname;
#     var validStartsWithUris = [
#         '/app/cart',
#         '/app/order',
#         '/app/goods',
#         '/app/goods/detail',
#         '/app/goods'
#     ];
#
#     if (validStartsWithUris.some(function (uri) {
#         return pathname.startsWith(uri);
#     })) {
#         var sdkInstance = "appInsightsSDK";
#         window[sdkInstance] = "appInsights";
#         var aiName = window[sdkInstance], aisdk = window[aiName] || function (e) {
#             function n(e) {
#                 t[e] = function () {
#                     var n = arguments;
#                     t.queue.push(function () {
#                         t[e].apply(t, n)
#                     })
#                 }
#             }
#
#             var t = {config: e};
#             t.initialize = !0;
#             var i = document, a = window;
#             setTimeout(function () {
#                 var n = i.createElement("script");
#                 n.src = e.url || "https://az416426.vo.msecnd.net/scripts/b/ai.2.min.js", i.getElementsByTagName("script")[0].parentNode.appendChild(n)
#             });
#             try {
#                 t.cookie = i.cookie
#             } catch (e) {
#             }
#             t.queue = [], t.version = 2;
#             for (var r = ["Exception"]; r.length;) n("track" + r.pop());
#             if (n("setAuthenticatedUserContext"), n("clearAuthenticatedUserContext"), n("flush"), t.SeverityLevel = {
#                 Verbose: 0,
#                 Information: 1,
#                 Warning: 2,
#                 Error: 3,
#                 Critical: 4
#             }, !(!0 === e.disableExceptionTracking || e.extensionConfig && e.extensionConfig.ApplicationInsightsAnalytics && !0 === e.extensionConfig.ApplicationInsightsAnalytics.disableExceptionTracking)) {
#                 n("_" + (r = "onerror"));
#                 var o = a[r];
#                 a[r] = function (e, n, i, a, s) {
#                     var c = o && o(e, n, i, a, s);
#                     return !0 !== c && t["_" + r]({message: e, url: n, lineNumber: i, columnNumber: a, error: s}), c
#                 }, e.autoExceptionInstrumented = !0
#             }
#             return t
#         }(
#             {
#                 instrumentationKey: '69ce0c4f-f7d1-4bdc-901b-9aa1c2b1e74a',
#                 disableAjaxTracking: true,
#                 correlationHeaderExcludedDomains: ['*.hotjar.io', '*.hotjar.com', '*.google-analytics.com', '*.googletagmanager.com'],
#                 accountId: '' || getCookie('_ga').split('.').splice(-2).join('.')
#             }
#         );
#         window[aiName] = aisdk;
#
#     }
# </script>
#
#
#
# <link rel="stylesheet" type="text/css" href="//static.msscdn.net/ui/build/pc/css/goods.css?202105201000">
# <link type="text/css" rel="stylesheet" href="//static.msscdn.net/skin/musinsa/css/product.min.css?202104301547"/>
# <script src="//static.msscdn.net/skin/musinsa/js/jquery.lazyload.min.js?20160119"></script>
#
#
#
# <script>
#     var dataLayer = window.dataLayer || [],
#         stateAll = {"params":{"goodsNo":"1755609","goodsSub":"0","sort":"new","selectSimilarNo":"","isSecret":"0","isCache":"Y","sex":0,"wh":"","loc":"","pGoodsNo":"","cacheFlush":"","rcdr":""},"IS_LOGIN":"N","app_yn":"N","goods_no":"1755609","goods_sub":"0","productInfo":{"goods_nm":"Half  Zip-Up M-Logo Sweat  (JM5TSU838MG)","goods_nm_eng":"Half  Zip-Up M-Logo Sweat  (JM5TSU838MG)","sale_stat_cl":"40","sex":"2","acc_buy_yn":"Y","category":"Top > \uae30\ud0c0 \uc0c1\uc758","baseCategoryName":"\uae30\ud0c0 \uc0c1\uc758","season_type_nm":"S\/S","similar_no":"1755606","normal_price":"69000","price":"48300","reg_dm":"20210120","brand":"jeep","opt_kind_cd":"CLOTHES","brand_nm":"\uc9c0\ud504","brand_nm_eng":"JEEP","size_opt_kind":"3191297","size_opt_kind_nm":"S","offline_com_id":"S","season":"2021","goods_type":"P","estimate_cnt":787,"com_id":"jngkorea","img":"\/images\/goods_img\/20210120\/1755609\/1755609_1_500.jpg","goods_no":"1755609","goods_sub":"0","restock_yn":"Y","sales_graph_data":"{}","orders_graph_yn":"Y","es_pageview_yn":"Y","img_prd_list":[{"type":"1","kind":"L","big_img":"\/images\/goods_img\/20210120\/1755609\/1755609_1_big.jpg","img":"\/images\/goods_img\/20210120\/1755609\/1755609_1_500.jpg","thumb_img":"\/images\/goods_img\/20210120\/1755609\/1755609_1_60.jpg","img_ext":"jpg","width":null,"height":null,"seq":"1","rep_yn":"Y","big_yn":"Y"},{"type":"1","kind":"D","big_img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_1_big.jpg","img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_1_500.jpg","thumb_img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_1_60.jpg","img_ext":"jpg","width":"1500","height":"1500","seq":"1","rep_yn":"Y","big_yn":"Y"},{"type":"2","kind":"D","big_img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_2_big.jpg","img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_2_500.jpg","thumb_img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_2_60.jpg","img_ext":"jpg","width":"1500","height":"1500","seq":"2","rep_yn":"N","big_yn":"Y"},{"type":"3","kind":"D","big_img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_3_big.jpg","img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_3_500.jpg","thumb_img":"\/images\/prd_img\/20210120\/1755609\/detail_1755609_3_60.jpg","img_ext":"jpg","width":"1500","height":"1500","seq":"3","rep_yn":"N","big_yn":"Y"}],"ptn_dc_yn":"N","limited_qty_yn":"","limited_min_qty":"1","limited_max_qty":"999","item_cat_cd":"001008","used_yn":"N","offline_goods_yn":"","item_cat_cds":{"cd1":"001","nm1":"\uc0c1\uc758","cd2":"001008","nm2":"\uae30\ud0c0 \uc0c1\uc758","cd3":"","nm3":""}},"userInfo":{"sex":"","email":""},"similarGoodsSearch":{"update_yn":"N","api_type":"syte"},"cardInfo":{"min_price":50000,"max_month":0},"goodsOpt":{"addopt_cnt":0,"first_option_cnt":4,"offline_option_yn":"N","option_cnt":1,"option_info":["S"],"option_info_str":"S"},"fit_count":0,"goods_list_all":["1755603","1755605","1755606","1855729","1783595","1783597","1809668","1884172","1186031","1884171","1746571","1848166","1420730","996177","1382658","1755605","1356896","1130844","1755603","1425234","1336398","1051406","1755606","1595528","1491644","996178","903340","1884191","1860814","1855729","1514578","1454812","1383418","1336290","1322019","1008043","1005683","1840098","1129745","324416","1755609"],"log_arr":{"goods_no":"1755609","goods_sub":"0","age":"","device":"pc","deviceKind":"","gender":"","location":"","parentsGoodsNo":"","previousLocation":"","referer":"","userId":"","userIp":"218.147.118.191","vid":""},"video":[],"SITE_LOWER":"musinsa","SITE_SEX":"","IS_APP":"N","domain":"store.musinsa.com","isOpenPlccService":true}
#     ;
#     stateAll.header_sex = '';
#     var goods_type = 'P';
#         var restock_yn = stateAll.productInfo.restock_yn,
#         offline_com_id = stateAll.productInfo.offline_com_id,
#         used_yn = stateAll.productInfo.used_yn,
#         goods_no = stateAll.productInfo.goods_no,
#         item_cat_nm2 = stateAll.productInfo.baseCategoryName,
#         similar_goods_update_yn = stateAll.similarGoodsSearch.update_yn
#     ;
#
#
#     try {
#         dataLayer.push({
#             'dimension12' : stateAll.productInfo.brand,
#             'productInfo' : {
#                 "email": stateAll.userInfo.email,
#                 "header_sex": stateAll.header_sex,
#                 "goods_no": stateAll.productInfo.goods_no,
#                 "goods_sub": stateAll.productInfo.goods_sub,
#                 "goods_nm": stateAll.productInfo.goods_nm,
#                 "category": stateAll.productInfo.item_cat_cds.nm1 + '>' + stateAll.productInfo.item_cat_cds.nm2,
#                 "category_ga": stateAll.productInfo.category,
#                 "brand": stateAll.productInfo.brand,
#                 "season": stateAll.productInfo.season + ' ' + stateAll.productInfo.season_type_nm,
#                 "sex": stateAll.productInfo.sex,
#                 "goods_type": stateAll.productInfo.goods_type,
#                 "price": stateAll.productInfo.price,
#                 "currency": "KRW"
#             }
#         });
#     }catch(e){
#         alert('죄송합니다. 내부 서버 문제로 페이지를 불러올 수 없습니다.');
#         location.href = '/';
#     }
#
# </script>
# </head><body>
# <!-- 팝업 공지사항 -->
#
# <!-- 상단 콘텐츠 영역 -->
#
#
#
# <script>
# 	var mss = {
# 		ui: {
# 			loggedIn: false,
# 			top: {
# 				extendBannerList: { // 상단 배너 리스트
# 					code: '16MAIN_UP_1_2',
# 					type: 'H',
# 					subject: '16MAIN_UP_1_2_메인 외_팬츠다무신사랑',
# 					contents: '<a href="/app/banner/check/16MAIN_UP_1_2/1"><span style="display:block;overflow:hidden; height:70px;background-color:#96B37C" href="https://store.musinsa.com/app/campaign/event/2021pants/133"><img src="//image.musinsa.com/images/banner/2021051710481000000066060.jpg" alt="무신사 팬츠 다무신사랑해"></span></a>',
# 					extendContents: '',
# 					extendUrl: ''
# 				},
# 				campaignList: [ // 캠페인 리스트
#
#
# 							{
# 								hrefTag: {
# 									linkUrl: '/app/campaign/event/musinsa_hyundaicard/129?eventCode=MSS06',
# 									style: 'color: #00D47B',
# 									text: '현대카드'
# 								}
# 							},
#
#
# 							{
# 								hrefTag: {
# 									linkUrl: '/app/campaign/event/2021pants/133',
# 									style: 'color: #ED0060',
# 									text: '팬츠'
# 								}
# 							},
#
#
# 				],
# 			},
# 			left: {
# 				category: {
# 					dCatCd: '', // 선택된 카테고리 코드
# 				},
# 			},
# 		}
# 	};
# </script>
#
#
# <div class="top-column column top-musinsa" style="display:none">
# 	<div id="short_top_special" class="header header-small store_header clearfix">
# 		<div class="main-wrapper wrapper">
# 			<h1 class="title"><a href="javascript:void(0)" onclick="showShortTopSpecial(); return false;">MUSINSA STORE 메뉴 열기</a></h1>
# 		</div>
# 	</div>
# </div>
#
# <div id="default_top" >
# 	<div id="topCommonPc"></div>
# </div>
#
# <script src="//static.msscdn.net/static/common/1.2.0/pc.js"></script><!--// 상단 콘텐츠 영역 -->
#
# <!-- wrap -->
# <div class="wrap" id="page_product_detail">
#     <!-- 왼쪽 메뉴 영역 -->
#     <div id="leftCommonPc"></div>
#
#     <!--// 왼쪽 메뉴 영역 -->
#
#     <!-- 오른쪽 콘텐츠 영역 -->
#     <div class="right_area page_detail_product">
#
#                 <!-- 상단 로케이션 -->
# <div class="pagenation pagenation_dropdown">
#     <div class="nav_sub">
#         <a href="/">무신사 스토어</a>
#         <span class="icon_entity">&gt;</span>
#         <a href="/app/contents/brandshop">브랜드숍</a>
#         <span class="icon_entity">&gt;</span>
#         <a href="https://display.musinsa.com/display/brands/jeep"><span>JEEP</span> (지프)</a>
#             </div>
#     <span class="txt_selected_division">
#                         			</span>
#     <div class="nav_sub_dropdown" style="display:none">
#         <ul>
#             <li><a href="javascript:void(0)">심플/베이직</a></li>
#             <li><a href="javascript:void(0)">트레디셔널</a></li>
#             <li><a href="javascript:void(0)">컨템포러리</a></li>
#             <li><a href="javascript:void(0)">트렌디/어번</a></li>
#             <li><a href="javascript:void(0)">뉴 웨이브</a></li>
#             <li><a href="javascript:void(0)">댄디/포멀</a></li>
#             <li><a href="javascript:void(0)">팝/유니크</a></li>
#             <li><a href="javascript:void(0)">심볼/팬시</a></li>
#             <li><a href="javascript:void(0)">하이 엔드</a></li>
#             <li><a href="javascript:void(0)">스트릿/힙합</a></li>
#             <li><a href="javascript:void(0)">마니아/컬처</a></li>
#             <li><a href="javascript:void(0)">밀리터리/텍티컬...</a></li>
#             <li><a href="javascript:void(0)">스포츠/아웃도어...</a></li>
#             <li><a href="javascript:void(0)">엑스게임/액션스포츠...</a></li>
#             <li><a href="javascript:void(0)">가방</a></li>
#             <li><a href="javascript:void(0)">시계</a></li>
#             <li><a href="javascript:void(0)">슈즈</a></li>
#             <li><a href="javascript:void(0)">액세서리</a></li>
#             <li><a href="javascript:void(0)">헤드웨어</a></li>
#             <li><a href="javascript:void(0)">아이웨어</a></li>
#             <li><a href="javascript:void(0)">일상용품</a></li>
#             <li><a href="javascript:void(0)">코스메틱</a></li>
#         </ul>
#     </div>
# </div>
# <!-- //상단 로케이션 -->
#
# <!--brandshop banner-->
#     <div class="detail_brand_banner">
#         <a href="https://display.musinsa.com/display/brands/jeep"><p class="brandBanner" style="BACKGROUND: url(//image.musinsa.com/images/brand/2020072814023100000046197.png) repeat-x 0px 0px"><img alt="" src="//image.musinsa.com/images/brand/2020072814023200000073815.png" /></p>
# </a>
#     </div>
# <!--//brandshop banner-->
#         <div class="right_contents section_product_summary">
#
#                         <div class="product_info">
#     <p class="item_categories">
#         <a href='https://search.musinsa.com/category/001'>상의</a> &gt; <a href='https://search.musinsa.com/category/001008'>기타 상의</a>
#                     <a href="https://search.musinsa.com/category/001008/?brand=jeep&page_kind=category">&#40;지프&#41;</a>
#             </p>
# </div>
# <p class="box_state">
#     <!-- [D] 세일 캠페인 뱃지 -->
#                                                 <span class="n-label label-limit">한정 판매</span>
#                                     <!--[D]래플 뱃지 추가-->
#                 <!--//[D]래플 뱃지 추가-->
#     </p>
# <span class="product_title">
#
#
#         <em>Half  Zip-Up M-Logo Sweat  (JM5TSU838MG)</em>
#     </span>
#
# <div class="share-block">
#     <!-- 페북공유 -->
#     <a href="javascript:void(0)" class="share-button" onclick="snsWin('f','%EC%A7%80%ED%94%84%28JEEP%29+Half++Zip-Up+M-Logo+Sweat++%28JM5TSU838MG%29+-+48%2C300+%7C+%EB%AC%B4%EC%8B%A0%EC%82%AC+%EC%8A%A4%ED%86%A0%EC%96%B4','https://store.musinsa.com/app/goods/1755609/0');dataLayer.push({'layerCategory': '상품상세','layerAction':'공유하기','layerLabel': 'facebook','event' : 'ga_event','nonInteraction' : false});">
#         <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="30" height="30" viewBox="0 0 30 30">
#     <defs>
#         <circle id="5y82mredia" cx="15" cy="15" r="15"/>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <g>
#             <g>
#                 <g transform="translate(-1430 -373) translate(270 250) translate(1160 123)">
#                     <mask id="g0ln4yhm7b" fill="#fff">
#                         <use xlink:href="#5y82mredia"/>
#                     </mask>
#                     <use fill="#3767B8" fill-rule="nonzero" xlink:href="#5y82mredia"/>
#                     <path fill="#FFF" d="M15.832 22.5v-6.842h2.212l.33-2.667h-2.542v-1.702c0-.772.207-1.299 1.273-1.299h1.36V7.605c-.236-.032-1.043-.105-1.982-.105-1.96 0-3.302 1.242-3.302 3.525v1.966h-2.217v2.667h2.217V22.5h2.651z" mask="url(#g0ln4yhm7b)"/>
#                 </g>
#             </g>
#         </g>
#     </g>
# </svg>    </a>
#     <!-- 트위터공유 -->
#     <a href="javascript:void(0)" class="share-button" onclick="snsWin('t','%EC%A7%80%ED%94%84%28JEEP%29+Half++Zip-Up+M-Logo+Sweat++%28JM5TSU838MG%29+-+48%2C300+%7C+%EB%AC%B4%EC%8B%A0%EC%82%AC+%EC%8A%A4%ED%86%A0%EC%96%B4','https://store.musinsa.com/app/goods/1755609/0');dataLayer.push({'layerCategory': '상품상세','layerAction':'공유하기','layerLabel': 'twitter','event' : 'ga_event','nonInteraction' : false});">
#         <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="30" height="30" viewBox="0 0 30 30">
#     <defs>
#         <circle id="impez0i0da" cx="15" cy="15" r="15"/>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <g>
#             <g>
#                 <g>
#                     <g transform="translate(-1470 -373) translate(270 250) translate(1160 123) translate(40)">
#                         <mask id="ln3z52jwmb" fill="#fff">
#                             <use xlink:href="#impez0i0da"/>
#                         </mask>
#                         <use fill="#1EA1F1" fill-rule="nonzero" xlink:href="#impez0i0da"/>
#                         <path fill="#FFF" d="M23 10.92c-.558.242-1.152.401-1.772.478.638-.374 1.124-.963 1.353-1.673-.594.35-1.25.595-1.95.733-.564-.592-1.369-.958-2.246-.958-1.703 0-3.074 1.36-3.074 3.028 0 .24.021.472.072.69-2.557-.122-4.82-1.328-6.34-3.166-.264.453-.42.972-.42 1.53 0 1.049.549 1.979 1.367 2.517-.495-.01-.98-.15-1.39-.373v.033c0 1.471 1.066 2.694 2.464 2.975-.25.067-.523.1-.806.1-.198 0-.396-.011-.583-.052.399 1.199 1.529 2.08 2.874 2.11-1.046.805-2.375 1.29-3.813 1.29-.253 0-.494-.01-.736-.041 1.362.865 2.977 1.359 4.717 1.359 5.66 0 8.753-4.616 8.753-8.616 0-.134-.005-.263-.011-.391.61-.427 1.123-.96 1.541-1.573" mask="url(#ln3z52jwmb)"/>
#                     </g>
#                 </g>
#             </g>
#         </g>
#     </g>
# </svg>    </a>
#     <!-- url 복사 -->
#     <a href="javascript:void(0)" class="share-button" id="url_copy_detail" onclick="dataLayer.push({'layerCategory': '상품상세','layerAction':'URL복사','layerLabel': '','event' : 'ga_event','nonInteraction' : false});">
#         <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="30" height="30" viewBox="0 0 30 30">
#     <defs>
#         <circle id="gg5hbjhooa" cx="15" cy="15" r="15"/>
#     </defs>
#     <g fill="none" fill-rule="evenodd">
#         <g>
#             <g>
#                 <g>
#                     <g transform="translate(-1510 -373) translate(270 250) translate(1160 123) translate(80)">
#                         <mask id="eb8wgkfp9b" fill="#fff">
#                             <use xlink:href="#gg5hbjhooa"/>
#                         </mask>
#                         <use fill="#B2B2B2" xlink:href="#gg5hbjhooa"/>
#                         <path fill="#FFF" fill-rule="nonzero" d="M9.597 18.632c1.581 0 2.632-1.09 2.632-2.931v-3.915h-.974v3.924c0 1.225-.636 1.977-1.658 1.977-1.022 0-1.659-.752-1.659-1.977v-3.924h-.974V15.7c0 1.841 1.051 2.931 2.633 2.931zm5.436-.096v-2.72l2.17 2.72h1.215l-2.218-2.72c.579-.048 1.012-.26 1.33-.578.377-.376.58-.868.58-1.437 0-.579-.213-1.08-.58-1.437-.356-.366-.867-.578-1.542-.578h-1.929v6.75h.974zm.868-3.626h-.868v-2.199h.868c.415 0 .694.107.887.3.183.192.3.472.3.8 0 .318-.107.598-.3.79-.193.184-.463.309-.887.309zm7.683 3.626v-.926h-2.748v-5.824h-.974v6.75h3.722z" mask="url(#eb8wgkfp9b)"/>
#                     </g>
#                 </g>
#             </g>
#         </g>
#     </g>
# </svg>        <input type="hidden" name="copyUrl_detail" value="http://mss.kr/1755609">
#     </a>
# </div>
#                         <div class="wrap_product">
#
#                                 <div class="product_left">
#                     <!--상품 줌이미지-->
# <div id="big_box" class="product_zoom spotlightActive" style="display:none">
#     <div class="product_img_zoom minus_cursor spotlight" id="big_img_area">
#         <img src="" id="big_img" alt="" style="position: relative; width: 1500px;" onclick="image_zoom.hideLayer('big_box');"/>
#         <span class="product_arrow_prev"><a href="javascript:void(0)" onClick="image_zoom.rollImage('detail_thumb', 'big_img', 'prev'); return false;"><i class="ic-22-line-arrow-left ic-white">이전상품사진</i></a></span>
#         <span class="product_arrow_next"><a href="javascript:void(0)" onClick="image_zoom.rollImage('detail_thumb', 'big_img', 'next'); return false;"><i class="ic-22-line-arrow-right ic-white">다음상품사진</i></a></span>
#     </div>
#     <span class="btn_close_pop" onclick="image_zoom.hideLayer('big_box');">close</span>
# </div>
# <!--//상품 줌이미지-->
#
#
#     <div id="detail_bigimg" class="product_img_basic">
#                     <span class="product_arrow_prev">
#                 <a href="javascript:;" onClick="rollImage('0','4', 'bigimg');" >
#                     <i class="ic-22-line-arrow-left ic-white">이전상품사진</i>
#                 </a>
#             </span>
#                                                                             <div class="product-img">
#                     <img src="//image.msscdn.net/images/goods_img/20210120/1755609/1755609_1_500.jpg" width="500" title="" alt="지프(JEEP) Half  Zip-Up M-Logo Sweat  (JM5TSU838MG)" id="bigimg" class="plus_cursor" onclick="image_zoom.showLayer('big_box', 'big_img', 'detail_thumb', currentImageIdx);" /><span class="vertical_standard"></span>
#                 </div>
#                                                                                                     <span class="product_arrow_next">
#                 <a href="javascript:;" onClick="rollImage('1','4', 'bigimg');">
#                     <i class="ic-22-line-arrow-right ic-white">다음상품사진</i>
#                 </a>
#             </span>
#                 <div class="n-label-group">
#                                                 </div>
#             </div>
#     <!--상품 썸네일-->
#     <div id="detail_thumb">
#         <ul class="product_thumb">
#                             <li onclick="changeImg('thum_0', 'bigimg', '0', 'Y');" style="cursor: pointer;" class="selected"><!-- class="selected" -->
#                     <img src="//image.msscdn.net/images/goods_img/20210120/1755609/1755609_1_60.jpg" alt="thum" width="60"  id="thum_0" big_yn="Y" style="display: inline-block; vertical-align: middle"/><span class="vertical_standard"></span>
#                 </li>
#                             <li onclick="changeImg('thum_1', 'bigimg', '1', 'Y');" style="cursor: pointer;" ><!-- class="selected" -->
#                     <img src="//image.msscdn.net/images/prd_img/20210120/1755609/detail_1755609_1_60.jpg" alt="thum" width="60"  id="thum_1" big_yn="Y" style="display: inline-block; vertical-align: middle"/><span class="vertical_standard"></span>
#                 </li>
#                             <li onclick="changeImg('thum_2', 'bigimg', '2', 'Y');" style="cursor: pointer;" ><!-- class="selected" -->
#                     <img src="//image.msscdn.net/images/prd_img/20210120/1755609/detail_1755609_2_60.jpg" alt="thum" width="60"  id="thum_2" big_yn="Y" style="display: inline-block; vertical-align: middle"/><span class="vertical_standard"></span>
#                 </li>
#                             <li onclick="changeImg('thum_3', 'bigimg', '3', 'Y');" style="cursor: pointer;" ><!-- class="selected" -->
#                     <img src="//image.msscdn.net/images/prd_img/20210120/1755609/detail_1755609_3_60.jpg" alt="thum" width="60"  id="thum_3" big_yn="Y" style="display: inline-block; vertical-align: middle"/><span class="vertical_standard"></span>
#                 </li>
#                                 </ul>
#         <!--//상품 썸네일-->
#     </div>
#
#
#     <div class="box_material">
#         <!--사이즈정보-->
#                     <h4 class="title-box font-mss">Size Info<span class="korSub">사이즈정보</span></h4>
#             <div class="box_size improve">
#                 <a href="javascript:void(0)" onclick="write_size(21, '001008'); return false;"><strong>구매내역 실측 선택</strong></a>
#                 <a href="javascript:void(0)" onclick="goMySize('21'); return false;"><strong>실측 직접 입력</strong></a>
#                 <a href="javascript:void(0)" onclick="window.open('/app/product/real_size#21','realsize', 'width=360, height=845, scrollbars=yes, resizalbe=no, left=400, top=100'); return false;"><strong>측정법</strong></a>
#             </div>
#             <!--//사이즈추천 개선 - 버튼-->
#             <!--사이즈추천 개선-->
#             <table id="size_table" class="table_th_grey">
#                 <thead>
#                 <tr>
#                     <th>cm</th>
#                                                                         <th class="item_val">
#                                 <input type="hidden" name="diff_range_0" value="5" />
#                                 총장
#                             </th>
#                                                                                                 <th class="item_val">
#                                 <input type="hidden" name="diff_range_1" value="5" />
#                                 어깨너비
#                             </th>
#                                                                                                 <th class="item_val">
#                                 <input type="hidden" name="diff_range_2" value="5" />
#                                 가슴단면
#                             </th>
#                                                                                                 <th class="item_val">
#                                 <input type="hidden" name="diff_range_3" value="5" />
#                                 소매길이
#                             </th>
#                                                             </tr>
#                 </thead>
#                 <tbody>
#                 <tr id="mysize">
#                     <th>MY</th>
#                                             <td colspan="5">가지고 계신 제품의 실측을 입력해 보세요~!</td>
#                                     </tr>
#                 <tr class="order_size_save" id="save_mysize" style="display:none">
#                     <td colspan="6">
#                         <a href="javascript:void(0)" onClick="save_size('21'); return false;">위 구매 내역의 사이즈를 저장하시겠습니까?</a>
#                         <input type="hidden" name="size_info" value=""/>
#                     </td>
#                 </tr>
#                                     <tr>
#                                                                                     <th>S</th>
#                                                                                                                 <td class="goods_size_val">65.1</td>
#                                                                                                                 <td class="goods_size_val">50.8</td>
#                                                                                                                 <td class="goods_size_val">57.2</td>
#                                                                                                                 <td class="goods_size_val">58.1</td>
#                                                                         </tr>
#                                     <tr>
#                                                                                     <th>M</th>
#                                                                                                                 <td class="goods_size_val">68.6</td>
#                                                                                                                 <td class="goods_size_val">54.6</td>
#                                                                                                                 <td class="goods_size_val">61</td>
#                                                                                                                 <td class="goods_size_val">64.1</td>
#                                                                         </tr>
#                                     <tr>
#                                                                                     <th>L</th>
#                                                                                                                 <td class="goods_size_val">69.9</td>
#                                                                                                                 <td class="goods_size_val">55.9</td>
#                                                                                                                 <td class="goods_size_val">63.5</td>
#                                                                                                                 <td class="goods_size_val">64.8</td>
#                                                                         </tr>
#                                     <tr>
#                                                                                     <th>XL</th>
#                                                                                                                 <td class="goods_size_val">71.1</td>
#                                                                                                                 <td class="goods_size_val">57.2</td>
#                                                                                                                 <td class="goods_size_val">67.3</td>
#                                                                                                                 <td class="goods_size_val">64.8</td>
#                                                                         </tr>
#                                 </tbody>
#             </table>
#             <ul class="n-info-txt">
#                 <li>위 사이즈표는 무신사스토어 측정방식을 기준으로 작성되었습니다. </li>
#                 <li>기존에 가지고 계신 옷 실측을 입력하시면 정확한 비교가 가능합니다.</li>
#                 <li>하단의 상품 상세 설명란의 사이즈표는 업체 기준 측정입니다.</li>
#             </ul>
#             <div class="product-note-box">
#                 <i class="ic-30-stencil-exclamation"></i>
#                 <ul class="n-info-txt">
#                     <li>모니터해상도, 컬러설정에 따라 제품이 왜곡되거나 컬러가 다르게 보일 수 있습니다.</li>
#                     <li>사이즈 실측의 경우 제품의 특성및 측정방식에 따라 오차가 발생할 수 있습니다.</li>
#                 </ul>
#             </div>
#                 <!--//사이즈정보-->
#     </div>
#
# <!--사이즈 소재 정보-->
#     <div class="box_material">
#         <h4 class="title-box font-mss">Guide<span class="korSub">가이드</span></h4>
#         <table class="table-simple">
#             <tbody>
#                             <tr>
#
#                     <th>핏</th>
#                                             <td>스키니</td>
#                                                                     <td>슬림</td>
#                                                                     <td class="active">레귤러</td>
#                                                                     <td class="active">루즈</td>
#                                                                     <td>오버 사이즈</td>
#
#                                                         </tr>
#                             <tr>
#
#                     <th>촉감</th>
#                                             <td>부드러움</td>
#                                                                     <td>약간 부드러움</td>
#                                                                     <td class="active">보통</td>
#                                                                     <td>약간 뻣뻣함</td>
#                                                                     <td>뻣뻣함</td>
#
#                                                         </tr>
#                             <tr>
#
#                     <th>신축성</th>
#                                             <td>없음</td>
#                                                                     <td>거의 없음</td>
#                                                                     <td class="active">보통</td>
#                                                                     <td>약간 있음</td>
#                                                                     <td>있음</td>
#
#                                                         </tr>
#                             <tr>
#
#                     <th>비침</th>
#                                             <td>있음</td>
#                                                                     <td>약간 있음</td>
#                                                                     <td class="active">보통</td>
#                                                                     <td>거의 없음</td>
#                                                                     <td>없음</td>
#
#                                                         </tr>
#                             <tr>
#
#                     <th>두께</th>
#                                             <td>얇음</td>
#                                                                     <td>약간 얇음</td>
#                                                                     <td class="active">보통</td>
#                                                                     <td>약간 두꺼움</td>
#                                                                     <td>두꺼움</td>
#
#                                                         </tr>
#                             <tr>
#
#                     <th>계절</th>
#                                             <td class="active">봄</td>
#                                                                     <td>여름</td>
#                                                                     <td class="active">가을</td>
#                                                                     <td>겨울</td>
#
#                                                                                             <td>&nbsp;</td>
#                                                             </tr>
#                         </tbody>
#         </table>
#     </div>
# <!-- //사이즈 소재 정보-->                </div>
#
#                                 <div id="product_order_info" class="product_right product_order_info" style="padding-left:15px">
#
#
# <div class="explan_product product_info_section">
#                         <div class="exclusive_info">
#                 <b>한정 판매</b>
#                 <p>무신사 스토어를 포함한 제한된 판매처에서만 구매 가능한 상품입니다.</p>
#             </div>
#                     <h4 class="title-box font-mss">Product Info<span class="korSub">제품정보</span></h4>
#     <ul class="product_article">
#         <li>
#             <p class="product_article_tit">브랜드 <span class="txt_unit2">&#47;</span> 품번 </p>
#             <p class="product_article_contents"><strong><a href="https://display.musinsa.com/display/brands/jeep">JEEP</a> <span class="txt_unit2">&#47;</span> JM5TSU838MG</strong></p>
#         </li>
#                 <li>
#             <p class="product_article_tit">
#                                 <span class="tooltip">
#                     <a class="ui-toggle-btn">시즌 <i class="ic-22-stencil-question ic-gray6">도움말 보기</i></a>
#                     <span class="n-tooltip tooltip-musinsa fade-in">이전 시즌과 동일하게 재생산된 제품은, 캐리오버 또는 최종으로 생산된 시즌을 기준으로 표시될 수 있습니다.</span>
#                 </span>
#                 <span class="txt_unit2">&#47;</span>
#                  성별
#             </p>
#             <p class="product_article_contents">
#                                     <strong> 2021                          S/S
#                                             </strong>
#                     <span class="txt_unit2">&#47;</span>
#                                 <span class="txt_gender">
#                                             <span>남</span>
#                                                                                                 </span>
#             </p>
#         </li>
#                 <li id="li_pageview_1m" style="display:none;">
#             <p class="product_article_tit">조회수(1개월)</p>
#             <p class="product_article_contents">
#                 <strong id="pageview_1m"></strong>
#             </p>
#         </li>
#                     <li id="li_sales_1y" style="display:none;">
#                 <p class="product_article_tit">누적판매(1년)</p>
#                 <p class="product_article_contents"><strong id="sales_1y_qty"></strong><span class="pageview_number">(결제완료-반품)</p>
#             </li>
#                 <!--좋아요-->
#         <li class="product_section_like hide" id="product-top-like">
#             <p class="product_article_tit">좋아요</p>
#             <p class="product_article_contents goods_like_1755609"><img src="//image.msscdn.net/skin/musinsa/images/icon_like_small_on.png" alt="" />
#                 <span class="prd_like_cnt">0</span>
#             </p>
#         </li>
#         <!--//좋아요-->
#
#                     <li>
#                 <p class="product_article_tit">
#                     구매 후기
#                                             <span class="tooltip">
#                             <a class="ui-toggle-btn"><i class="ic-22-stencil-question ic-gray6">도움말 보기</i></a>
#                             <span class="n-tooltip tooltip-musinsa fade-in">모든 컬러의 상품 후기가 통합 노출됩니다.<br>하단에서 필터로 컬러별 후기를 조회할 수 있습니다.</span>
#                         </span>
#                                     </p>
#                 <p class="product_article_contents">
#                     <a href="#estimateBox" class="prd-score__link">
#                         <span class="img-score"><span class="bar" style="width: 95%"></span></span>
#                                                 <span class="prd-score__rating">4.8</span>
#                         <span class="prd-score__bar">/</span>
#                         <span class="prd-score__review-count">후기 787개 보기</span>
#                     </a>
#                 </p>
#
#             </li>
#                         <li class="article-tag-list list">
#             <p class="product_article_contents">
#                                     <a href="https://search.musinsa.com/search/musinsa/integration?q=%EC%8A%A4%EC%9B%A8%ED%8A%B8%EC%85%94%EC%B8%A0" class="listItem">#스웨트셔츠</a>
#                                     <a href="https://search.musinsa.com/search/musinsa/integration?q=%EC%98%A4%EB%B2%84%EC%82%AC%EC%9D%B4%EC%A6%88" class="listItem">#오버사이즈</a>
#                                     <a href="https://search.musinsa.com/search/musinsa/integration?q=%EB%A7%A8%ED%88%AC%EB%A7%A8%ED%8B%B0%EC%85%94%EC%B8%A0" class="listItem">#맨투맨티셔츠</a>
#                                     <a href="https://search.musinsa.com/search/musinsa/integration?q=%EC%8A%A4%EC%9B%BB%EC%85%94%EC%B8%A0" class="listItem">#스웻셔츠</a>
#                                     <a href="https://search.musinsa.com/search/musinsa/integration?q=%EB%A7%A8%ED%88%AC%EB%A7%A8" class="listItem">#맨투맨</a>
#                                     <a href="https://search.musinsa.com/search/musinsa/integration?q=%EC%A7%91%EC%97%85" class="listItem">#집업</a>
#                                     <a href="https://search.musinsa.com/search/musinsa/integration?q=%EC%A7%80%ED%94%84%C3%97%EC%A7%80%ED%94%84%EC%B0%A8" class="listItem">#지프×지프차</a>
#                             </p>
#         </li>
#             </ul>
# </div>
# <!--//제품정보-->
#
#     <a href="#" id="graph_summary_area" class="explan_product n-stats-summary"
#        style="display:none;"></a>
#
#                                                     <div class="explan_product delivery_info_section">
#         <h4 class="title-box font-mss">Delivery Info<span class="korSub">배송정보</span></h4>
#         <ul class="product_article">
#
#             <li class="box_info_products">
#                 <p class="product_article_tit">배송 방법</p>
#                 <p class="product_article_contents">국내 배송 <span class="txt_unit2">&#47;</span>  입점사 배송</p>
#             </li>
#             <li>
#                 <p class="product_article_tit">
#                     <span class="tooltip">
#                         <a class="ui-toggle-btn">출고 기간 <i class="ic-22-stencil-question ic-gray6">도움말 보기</i></a>
#                         <span class="n-tooltip tooltip-musinsa fade-in">상품 결제 후 택배사에 상품이 전달되기까지 소요되는 기간입니다.<br>판매자 또는 택배사의 사정에 따라 실제 출고 기간과 차이가 있을 수 있습니다.</span>
#                     </span>
#                 </p>
#                 <p class="product_article_contents del">평균 0.8일 <span class="txt_unit2">&#47;</span> 주말, 공휴일 제외</p>
#                                             </li>
#         </ul>
#             </div>
# <!--//배송정보-->
#                                                 <!-- 가격정보 -->
#
# <div class="explan_product price_info_section">
#     <h4 class="title-box font-mss">Price Info<span class="korSub">가격정보</span></h4>
#     <ul class="product_article">
#
#                             <li id="normal_price" style="display: none;">69000</li>
#             <li class="box_info_products">
#                 <p class="product_article_tit">무신사 판매가</p>
#                 <p class="product_article_contents">
#                     <span class="product_article_price" id="goods_price">
#                                                                                                                                                                                                                                                                                     <del class="price-del">69,000원</del>
#                     </span>
#                                                                                     <span class="txt_timesale" id="time_sale_1755609"></span>                </p>
#             </li>
#             <!-- 오프라인 상품 여부 -->
#                                             <li class="box_info_products">
#                     <p class="product_article_tit">무신사 회원가</p>
#                     <div class="product_article_contents">
#                         <a href="javascript:void(0)" onClick="viewGoodsMemberPrice('sPrice', '1755609', '0'); return false;" class="product_article_price">
#                                                             <span id="list_price"><span class="txt_unit_price">원</span><i class="ic-18-line-arrow-bottom"></i></span>
#                                                                 <p class="product_discount_svg">
#                                     <svg width="11" height="10" viewBox="0 0 11 10" fill="none" xmlns="http://www.w3.org/2000/svg">
#                                         <path fill-rule="evenodd" clip-rule="evenodd" d="M8 0H3V4H0L5.5 10L11 4H8V0Z" fill="#FF0000"/>
#                                     </svg>
#                                 </p>
#                                 <span class="txt_kor_discount">
#                                     30%
#                                      이상 할인                                </span>
#                                                                                     </a>
# ...
#                         </ul>
#                         <div class="packing-img"></div>
#                     </div>
#                 </div>
#
#             </div>
#             <div class="cs-info-block">
#                 <div class="block-tit"><strong>고객센터</strong></div>
#                 <div class="cs-cont">
#                     <div class="cont-label font-mss">1544-7199</div>
#                     <div class="cont-info">
#                         <div class="cs-connect">1번 배송 / 교환 / 환불관련<br>2번 결제 / 회원 관련</div>
#                         <div>상품 문의 > 각 상품 Q&A 이용<br>평일 09:00~18:00 / 토,일,공휴일 휴무</div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
# <!--//cs안내-->
#
#         <!-- 하단 콘텐츠 영역 -->
#                                 <div id="footerCommonPc"></div>
# <meta name="google-site-verification" content="NqB0BDAEWJTvAPCCxzrckJYnS7-xJILFU40FvSmh5S8" />
# <script type="text/javascript" src="//static.msscdn.net/skin/musinsa/js/jquery.url.packed.js" async="true"></script>                <!--// 하단 콘텐츠 영역 -->
#
#         <!--// 오른쪽 콘텐츠 영역 -->
#
#                 <div id="memberCertifyNone" class="ui-layer layer-basic">
#             <h1 class="layer-tit tit-full">본인인증(미인증) 회원입니다.</h1>
#             <div class="layer-cont">지금 인증하고 서비스를 편리하게 이용해보세요.<br>(나중에 하기 선택 시 인증 없이 주문 가능하며 해당 팝업은 7일간 열리지 않습니다.)</div>
#             <div class="btn-set">
#                 <button type="button" class="ui-layer-close n-btn btn-lighter delay-btn">나중에 하기</button>
#                 <button type="button" class="ui-layer-close n-btn btn-accent check-cert-btn">본인인증 하기</button>
#             </div>
#         </div>
#
#
#     <script type="text/javascript">
#         $(window).on('load', function(){
#             $('.layer-suggest-join').animate({
#                 opacity:1,
#                 right:'64px'
#             },500);
#         });
#
#         function closeEvent(type){
#             if(type == "day"){
#                 setTodayCookie("user_join_event", 1, 1);
#             }
#             $('.layer-suggest-join').remove();
#         }
#
#         function setTodayCookie(key, value, expire){
#             var todayDate = new Date();
#             todayDate = new Date(parseInt(todayDate.getTime() / 86400000) * 86400000 + 54000000);
#             if ( todayDate > new Date() )
#             {
#                 expire = expire - 1;
#             }
#             todayDate.setDate( todayDate.getDate() + expire );
#             document.cookie = key + "=" + escape( value ) + "; path=/; expires=" + todayDate.toGMTString() + "; domain=.musinsa.com"
#         }
#     </script>
#
#     <div class="popup_info layer-suggest-join">
#         <div class="wrap-suggest-join">
#             <a href="javascript:void(0);" class="btn-close" onclick="closeEvent('day');return false;"><img src="//image.msscdn.net/skin/musinsa/images/btn_x_23_thin.png" alt="오늘 하루 열지 않기" /></a>
#             <h4>무신사 회원혜택</h4>
#             <p>회원 등급 할인, 적립금, 정기 쿠폰 등<br>다양한 회원 혜택을 받으세요.</p>
#             <p>신규 가입 시, 최대 15만원 할인 쿠폰팩<br>무신사 스탠다드 990원 구매 기회</p>
#             <a href="https://my.musinsa.com/member/v2/join" class="btn-block-important">회원 가입하기</a>
#             <a href="/app/content/s/usr/membership" class="btn-block-important join">신규 회원 이벤트</a>
#             <div class="link-box">
#                 <a href="https://my.musinsa.com/login/v1/login?referer=http%3A%2F%2Fstore.musinsa.com%2Fapp%2Fgoods%2F1755609" class="link-login">로그인 하기</a>
#                 <a href="javascript:void(0);" class="day-popup-open" onclick="closeEvent('day');return false;">오늘 하루 열지 않기</a>
#             </div>
#         </div>
#     </div>
#
#     </div>
# </div>
# <!--// wrap -->
#
#
# <div id="pop_order_size" class="layer_order_size" style="display:none"></div>
#
# <!--smart search layer-->
#                             <div id="wrap-smartsearch-layer" class="layer_position wrap-smartsearch-layer" style="display:none">
#     <div class="layer-smartsearch">
#         <div class="box-left">
#             <img src="//image.msscdn.net/images/goods_img/20210120/1755609/1755609_1_500.jpg"
#                  width="500" title="" alt="지프(JEEP) Half  Zip-Up M-Logo Sweat  (JM5TSU838MG)" id="bigimg"/><span class="vertical_standard" style="height:600px"></span>
#         </div>
#
#         <h4 class="title">이미지 서치</h4>
#         <a class="btn-close" href="javascript:void(0)"><i class="ic-30-line-close">이미지 서치 팝업 닫기</i></a>
#         <div class="wrap-scroll">
#             <ul id="image_matching_holder" class="list-product"></ul>
#             <img src="//image.msscdn.net/skin/musinsa/images/loading2.gif" alt="loading" id="smartsearch_loading" style="margin:50% 45%"/>
#             <input type="hidden" id="search_page" value="1"/>
#             <input type="hidden" id="display_cnt" value="12"/>
#         </div>
#     </div>
# </div>
#
# <!--무이자 할부 레이어-->
# <div id="viewCardList" class="wrap-benefit-cart-pop" style="display:none">
#     <div class="popup_info layer-card-benefit">
#         <p class="box_title">
#             <span class="title-box"><strong>카드사 할부</strong><span class="korSub">(결제 금액 기준)</span></span>
#             <a class="btn_close_pop" href="javascript:void(0)" onClick="viewCardList(); return false;"><img src="//image.msscdn.net/skin/musinsa/images/btn_close_pop.png" alt="닫기" /></a>
#         </p>
#         <div class="tabBox">
#             <ul class="snb snb-2">
#                 <li class="box-tab-btn tab-btn btn active" data-for="free"><span>무이자 할부</span></li>
#                 <li class="box-tab-btn tab-btn btn " data-for="part"><span>부분 무이자</span></li>
#             </ul>
#             <!--무이자 할부-->
#             <div class="tab free">
#                 <ul>
#                                                                                                                                                                                                                                                                                                                                                                                                     </ul>
#             </div>
#             <!--부분 무이자-->
#             <div class="tab part">
#                 <ul>
#                     <ul class="box-part-benefit">
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                             </ul>
#             </div>
#         </div>
#     </div>
# </div>
# <!--//무이자 할부 레이어-->
#
# <!--래플 안내-->
# <div id="raffle_info" class="layer_cont layer-raffle-info" style="display:none; position: fixed; top:215px;">
#     <div class="tit">래플</div>
#     <div class="info">소비자에게 공정한 기회와 편의를 제공하고자 도입한 온라인 추첨 구입 제도 입니다.<br />당첨되신 분들께는 무신사스토어를 통해 해당 상품을 구매할 수 있는 기회가 제공됩니다.</div>
#             <div class="raffle-route">
#             <ul>
#                 <li class="step-app">
#                     <i></i>
#                     <div>
#                         <span>무신사 앱 접속</span>
#                         앱을 통해서만 응모<br />가능합니다.
#                     </div>
#                 </li>
#                 <li class="step-login">
#                     <i></i>
#                     <div>
#                         <span>무신사 로그인</span>
#                         회원만 1인 1회 응모<br />가능합니다.
#                     </div>
#                 </li>
#                 <li class="step-fill">
#                     <i></i>
#                     <div>
#                         <span>응모 정보 작성</span>
#                         정보가 잘못 입력될 시<br />응모가 취소될 수 있습니다.
#                     </div>
#                 </li>
#                 <li class="step-enter">
#                     <i></i>
#                     <div>
#                         <span>응모하기</span>
#                         응모 후, 완료 팝업을 꼭<br />확인해 주세요.
#                     </div>
#                 </li>
#                 <li class="step-result">
#                     <i></i>
#                     <div>
#                         <span>결과 확인</span>
#                         당첨여부는 SMS<br />(알림톡)로 안내됩니다.
#                     </div>
#                 </li>
#                 <li class="step-buy">
#                     <i></i>
#                     <div>
#                         <span>구매 하기</span>
#                         당첨자에 한하여 발송된<br />URL에 접속하여 구매하세요.<br />제한된 시간 내에만 구입이 가능합니다.
#                     </div>
#                 </li>
#             </ul>
#         </div>
#         <ul class="list-explain">
#         <li>상품 별로 응모기간과 발표일, 구매 기간이 다릅니다.</li>
#         <li>당첨자는 100% 랜덤 추첨됩니다.</li>
#     </ul>
#
#     <a class="btn-close" href="javascript:void(0);"><i class="ico ico-close">레이어 팝업 닫기</i></a>
# </div>
# <!--//래플 안내-->
#
# <!--래플응모결과 없음-->
# <div id="notexist_popup_wrap" class="popup-wrap" style="width: 100%; height: 100%; position: fixed; display: none; flex-direction: column;  top: 0; z-index: 99999;">
#     <div id="notexist_popup" class="layer_cont layer-raffle-none" style="display: none;">
#         <a class="btn-close" href="javascript:void(0);" onclick="return false;"><i class="ico ico-close">레이어 팝업 닫기</i></a>
#         <div id="notexist_title" class="tit">Half  Zip-Up M-Logo Sweat  (JM5TSU838MG)</div>
#         <div class="info">래플에 응모하신 내역이 없습니다.</div>
#     </div>
# </div>
# <!--//래플응모결과 없음-->
#
# <!--래플 당첨결과-->
# <div id="raffle_result_wrap" class="popup-wrap" style="position:absolute;display:none;top:0;z-index:99999;width:100%;min-width:1560px;">
#     <div class="layer_cont layer-raffle-result" id="raffle_result" style="display: none;"></div>
# </div>
# <!--//래플 당첨결과-->
#
#
# <!--[D]사은품 레이어-->
# <div id="getgiftLayer" class="ui-layer layer-basic layer-gift-area">
#     <div class="pop-cont gift-area">
#         <p class="txt"><span>0원</span> 이상 구매시 사은품 증정</p>
#         <p>특정 상품 추가 구매 시 사은품을 증정합니다.</p>
#         <div class="info" data-apply-amt="">
#             <div class="img-area"><img src="" alt=""></div>
#             <progress value="0" max="100" class="progressbar-value" id="progressbar"></progress>
#             <p class="price"><span></span> / 0원</p>
#         </div>
#         <a href="javascript:void(0);" class="pop-btn cart" onclick="addCart('1','1755609','0','4', ''); return false;">장바구니 담고 적용상품 보기</a>
#         <a href="javascript:void(0);" class="pop-btn" onclick="prepareOrder.directOrder('1','1755609','0','4'); return false;">바로 구매하기</a>
#     </div>
# </div>
# <!--[D]//사은품 레이어-->
#
# <!-- [D]사은품 적용상품 레이어 -->
#
# <script type="text/javascript">
#     $(function() {
#         giftLayerHandler.showCartBtn = 1;
#     });
#
#     function addCart(optionCnt, goodsNo, goodsSub, firstOptionCnt, giftNo) {
#         var popAddCart = $(".pop-add-cart");
#         prepareOrder.addCart(optionCnt, goodsNo, goodsSub, firstOptionCnt, function (response, msg, redirectUrl) {
#             if (response === 1) {
#                 msg = '장바구니에 상품 1개가 추가 되었습니다.';
#                 loadCartTotal();
#                 $('#mini_cart > li').remove();
#             }
#             popAddCart.text(msg);
#
#             setTimeout(function(){
#                 $(".pop-add-cart").animate({top:"40px"}, {duration:300, easing:"easeOutCubic"});
#             },500);
#             setTimeout(function(){
#                 $(".pop-add-cart").animate({top:"-48px"}, {duration:300, easing:"easeInCubic"});
#             },3800);
#
#             if (redirectUrl) {
#                 document.location.href = redirectUrl;
#             } else {
#                 if (giftNo && giftNo!='') {
#                     giftLayerHandler.open(giftNo);
#                 }
#             }
#         });
#     }
#
#     function directOrder(optionCnt, goodsNo, goodsSub, firstOptionCnt, giftNo) {
#         if($("[name=buy_list_opt_noprice]").length == 0) {
#             alert("옵션을 선택해 주세요.");
#             return false;
#         }
#
#         if (giftNo) {
#             var info = $("#getgiftLayer .info");
#             var applyAmt = info.data('apply-amt');
#             var totalPrice = parseInt(unComma($(".sum-total-price > .price").html()));
#
#             var rate = (totalPrice && applyAmt) ? totalPrice / applyAmt * 100 : 0;
#
#             if (rate < 100) {
#                 info.find(".price > span").text([Comma(totalPrice), '원'].join(''));
#
#                 var progressbar = info.find('.progressbar-value');
#                 progressbar.attr('value', rate);
#                 progressbar.css('--value', rate + '%');
#                 uiLayerBasic('#getgiftLayer');
#                 return;
#             }
#         }
#         prepareOrder.directOrder(optionCnt, goodsNo, goodsSub, firstOptionCnt);
#     }
# </script>
#
#
# <div class="pop-add-cart"></div>
#
# <div id="layerGift" class="ui-layer layer-basic gift_pop">
#     <div class="cart_pop"></div>
#     <button type="button" class="ui-layer-close" onclick="giftLayerHandler.close(); return false;"><i class="ico ico-sm ico-close2">레이어 팝업 닫기</i></button>
# </div>
#
#
# <script type="text/javascript">
#     var giftSwiper = new Swiper('.product_list', {
#         slidesPerView:"auto",
#         observer :true,
#         observeParents:true,
#         pagination: {
#             el: '.gift-swiper-pagination',
#             type: 'fraction',
#         },
#         navigation: {
#             nextEl: '.gift-swiper-button-next',
#             prevEl: '.gift-swiper-button-prev',
#         }
#     });
#
#     // 장바구니 담기 시 Confirm -> Toast 변경
#     function addCartToast(optionCnt, goodsNo, goodsSub, firstOptionCnt) {
#         prepareOrder.addCart(optionCnt, goodsNo, goodsSub, firstOptionCnt, function (response, msg, redirectUrl) {
#             if (response === 1) {
#                 $('#select-purchase-Layer').removeClass('is-active');
#                 $('#duplicate_cart_toast').hide();
#                 $("#add_cart_toast").fadeIn(200).delay(2250).fadeOut(200);
#                 loadCartTotal();
#             } else if (response === -27) {
#                 $('#select-purchase-Layer').removeClass('is-active');
#                 $('#add_cart_toast').hide();
#                 $("#duplicate_cart_toast").fadeIn(200).delay(2250).fadeOut(200);
#             } else {
#                 alert(msg);
#                 if (redirectUrl) {
#                     document.location.href = redirectUrl;
#                 }
#             }
#         });
#     }
# </script>
#
# <!-- [D]//사은품 적용상품 레이어 --><input type="hidden" name="shop_domain" value="store.musinsa.com"/>
# <form name=f1>
#     <input type="hidden" name="popup"/>
# </form>
#
# <script
#         src="https://browser.sentry-cdn.com/6.2.0/bundle.tracing.min.js"
#         integrity="sha384-Z4qhO5iPVi3IJ9//F7/h6V6HxmpfDYFY2y7N6cYuCU4QUVfo5CcTB4hM+eNq0sQl"
#         crossorigin="anonymous"
# ></script>
# <script type="text/javascript">
#     if(!(navigator.userAgent.indexOf('MSIE') > 0 || navigator.userAgent.indexOf('Trident'))) {
#         try {
#             Sentry.init({
#                 dsn: "https://d318a11d96f94300b6c5460781c825e7@o464148.ingest.sentry.io/5474816",
#             });
#         } catch (e) {}
#     }
# </script>
#
# <script src="//static.msscdn.net/skin/musinsa/js/product_v3.js?202105211252"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/relative_cart.js?202105171800"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/gift_suggestion.js?202003171511"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/image_zoom.js?20160119"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/reviews.comments.js?202105211252"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/reviews.sns.js?202011021242"></script>
# <script src="//static.msscdn.net/skin/m_musinsa/js/owl.carousel.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/Chart.js/1.0.2/Chart.min.js"></script><!-- chart.js -->
# <script src="//static.msscdn.net/skin/musinsa/js/kakao.min.js?20160204_1"></script><!-- 카카오톡 관련 소스 //-->
# <script src="//static.msscdn.net/skin/musinsa/js/kakao.api.js?20191031"></script>
# <script src="//static.msscdn.net/skin/js/goods/goods_detail.js?v=202105211252"></script>
# <script src="//static.msscdn.net/skin/musinsa/js/goods/goods_detail.js?v=202105211252"></script>
# </body>
# </html>

# %% [markdown]
# ### GET방식 데이터 전송

# %%
data = {'name':'ronen'} # 딕셔너리 형
response = requests.get(URL, data=data) #뒤에 data에 알맞은 변수 전달. 

print(response.status_code) # [HTTP 상태코드](https://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C) 반환 -> 200 (정상 작동)
print(response.text) # 페이지 html 코드 반환.
# Out:
# 200
# <!DOCTYPE html>
# <html>
# <head>
# <title>크롤링 연습사이트 01</title>
# </head>
# <body>
# <h1>저의 첫 웹사이트 오신것을 환영합니다.</h1>
# <h1 title="welcome">인사이트캠퍼스.</h1>
# <h2>이곳은 크롤링 연습을 위한 웹사이트입니다.</h2>
# <table border="1">
#     <thead>
#       <tr>
#       	<th class="tablehead">이름</th>
#         <th class="tablehead">나이</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#           <td>이몽룡</td>
#           <td>34</td>
#       </tr>
#       <tr>
#           <td>홍길동</td>
#           <td>23</td>
#       </tr>
#      </tbody>
# </table>
# <p id="hello">
#     이탈리아 요리의 시작은 기원전 4세기로 거슬러 올라갈 수 있다. 대항해시대를 거치면서 아메리카 대륙에서 감자·토마토·후추·옥수수 등이 유입되어 그 종류와 풍미가 다양해졌고 현대에 이르러서는 피자와 파스타 등 많은 이탈리아 요리가 널리 퍼지게 되었다.
# </p>
# <p id="cook">
#     전통적인 요리법이나 양식은 상당한 차이가 있지만, 이탈리아 요리는 다른 국가의 요리 문화에서 다양한 영감을 줄 만큼 다양하고 혁신적인 것으로 평가되고 있다. 각 지방마다 고유의 특색이 있어 그 양식도 다양하지만 크게 북부와 남부로 나눌 수 있다. 다른 나라와 국경을 맞대고 있던 북부 지방은 산업화되어 경제적으로 풍족하고 농업이 발달해 쌀이 풍부해 유제품이 다양한 반면 경제적으로 침체되었던 남부 지방은 올리브와 토마토, 모차렐라 치즈가 유명하고 특별히 해산물을 활용한 요리가 많다. 식재료와 치즈 등의 차이는 파스타의 종류와 소스와 수프 등도 다름을 의미한다.
# </p>
# <a href="01.html">1페이지 바로가기</a>
# <a href="02.html">2페이지 바로가기</a>
# <a href="03.html">3페이지 바로가기</a>
# <a href="04.html">4페이지 바로가기</a>
# </body>
# </html>

# %% [markdown]
# # Beautiful Soup
# - HTML에서 손쉽게 원하는 데이터를 가져올수있도록 지원
# - pip install beautifulsoup4 로 패키지 설치
#
# [타깃 사이트 들어가기](https://scrapying-study.firebaseapp.com/01/)

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://scrapying-study.firebaseapp.com/01/'
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")
result = soup.find("title")
print(result)
print(result.text)
# Out:
# <title>크롤링 연습사이트 01</title>
# 크롤링 연습사이트 01

# %%
print("soup.find(\"p\")\n",soup.find("p")) # 가장 상단에 있는 p태그 하나만
print("soup.find_all(\"p\", limit=2)\n",soup.find_all("p", limit=2)) # 일치하는 모든 탸그(limit: 가져올 갯수제한., 생략가능)
print("soup.find(\"th\", \"tablehead\")\n",soup.find("th", "tablehead")) # 옵션값이 class가 tablehead인것
print("soup.find(\"th\", class_=\"tablehead\")\n",soup.find("th", class_="tablehead")) # 옵션값이 class가 tablehead인것
print("soup.find(\"th\", attrs={\"class\":\"tablehead\"})\n",soup.find("th", attrs={"class":"tablehead"})) # 옵션값이 class가 tablehead인것(옵션명 변경 가능)
print("soup.find(\"h1\", attrs={\"title\":\"welcome\"})\n",soup.find("h1", attrs={"title":"welcome"})) # 옵션값이 title가 welcome인것(옵션명 변경 가능)
print("soup.find(id=\"hello\")\n",soup.find(id="hello")) # 옵션값이 id가 hello인것.
# Out:
# soup.find("p")
#  <p id="hello">
#     이탈리아 요리의 시작은 기원전 4세기로 거슬러 올라갈 수 있다. 대항해시대를 거치면서 아메리카 대륙에서 감자·토마토·후추·옥수수 등이 유입되어 그 종류와 풍미가 다양해졌고 현대에 이르러서는 피자와 파스타 등 많은 이탈리아 요리가 널리 퍼지게 되었다.
# </p>
# soup.find_all("p", limit=2)
#  [<p id="hello">
#     이탈리아 요리의 시작은 기원전 4세기로 거슬러 올라갈 수 있다. 대항해시대를 거치면서 아메리카 대륙에서 감자·토마토·후추·옥수수 등이 유입되어 그 종류와 풍미가 다양해졌고 현대에 이르러서는 피자와 파스타 등 많은 이탈리아 요리가 널리 퍼지게 되었다.
# </p>, <p id="cook">
#     전통적인 요리법이나 양식은 상당한 차이가 있지만, 이탈리아 요리는 다른 국가의 요리 문화에서 다양한 영감을 줄 만큼 다양하고 혁신적인 것으로 평가되고 있다. 각 지방마다 고유의 특색이 있어 그 양식도 다양하지만 크게 북부와 남부로 나눌 수 있다. 다른 나라와 국경을 맞대고 있던 북부 지방은 산업화되어 경제적으로 풍족하고 농업이 발달해 쌀이 풍부해 유제품이 다양한 반면 경제적으로 침체되었던 남부 지방은 올리브와 토마토, 모차렐라 치즈가 유명하고 특별히 해산물을 활용한 요리가 많다. 식재료와 치즈 등의 차이는 파스타의 종류와 소스와 수프 등도 다름을 의미한다.
# </p>]
# soup.find("th", "tablehead")
#  <th class="tablehead">이름</th>
# soup.find("th", class_="tablehead")
#  <th class="tablehead">이름</th>
# soup.find("th", attrs={"class":"tablehead"})
#  <th class="tablehead">이름</th>
# soup.find("h1", attrs={"title":"welcome"})
#  <h1 title="welcome">인사이트캠퍼스.</h1>
# soup.find(id="hello")
#  <p id="hello">
#     이탈리아 요리의 시작은 기원전 4세기로 거슬러 올라갈 수 있다. 대항해시대를 거치면서 아메리카 대륙에서 감자·토마토·후추·옥수수 등이 유입되어 그 종류와 풍미가 다양해졌고 현대에 이르러서는 피자와 파스타 등 많은 이탈리아 요리가 널리 퍼지게 되었다.
# </p>

# %%
URL = 'https://scrapying-study.firebaseapp.com/01/'
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")
result = soup.find("a")
print(result.text) # .text - 태그내에 내용만 추출
print(result.attrs["href"]) # .attrs["옵션명"] - 태그내에 옵션을 추출

# 결과값에서 다시 검색가능
result = soup.find("table")
result2 = soup.find("table")
# Out:
# 1페이지 바로가기
# 01.html

# %% [markdown]
# # 실습 01

# %%
import re
URL = 'https://scrapying-study.firebaseapp.com/01/'
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")

re.sub("\n*(  )*",'',soup.find(id="cook").text)
# Out:
# '전통적인 요리법이나 양식은 상당한 차이가 있지만, 이탈리아 요리는 다른 국가의 요리 문화에서 다양한 영감을 줄 만큼 다양하고 혁신적인 것으로 평가되고 있다. 각 지방마다 고유의 특색이 있어 그 양식도 다양하지만 크게 북부와 남부로 나눌 수 있다. 다른 나라와 국경을 맞대고 있던 북부 지방은 산업화되어 경제적으로 풍족하고 농업이 발달해 쌀이 풍부해 유제품이 다양한 반면 경제적으로 침체되었던 남부 지방은 올리브와 토마토, 모차렐라 치즈가 유명하고 특별히 해산물을 활용한 요리가 많다. 식재료와 치즈 등의 차이는 파스타의 종류와 소스와 수프 등도 다름을 의미한다.'

# %% [markdown]
# # 실습 02

# %%
tablehead_list = []
tableitem_list = []
answer = []
for tr_item in soup.find_all("tr"):
    if tr_item.find_all("th", "tablehead") != []:
        tablehead_list = [re.sub("<\w*>[^<]",'',td_item.text) for td_item in tr_item.find_all("th", "tablehead")]
    else :
        tableitem_list += [[re.sub("<\w*>[^<]",'',td_item.text) for td_item in tr_item.find_all("td")]]

answer = [{tablehead_list[0]:tableitem_list[i][0], tablehead_list[1]:tableitem_list[i][1]} for i in range(len(tableitem_list)) ]

print(answer)
# Out:
# [{'이름': '이몽룡', '나이': '34'}, {'이름': '홍길동', '나이': '23'}]

# %% [markdown]
# # 실습 03

# %%
import requests
from bs4 import BeautifulSoup
URL = "https://scrapying-study.firebaseapp.com/01/"
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")
for i in soup.find_all("a"):
    response = requests.get(URL+i["href"])
    soup = BeautifulSoup(response.text, "html.parser")
    print(soup.find("p").text.strip())
#
# Out:
# 크롤링 연습사이트 01-1 페이지입니다.
# 크롤링 연습사이트 01-2 페이지입니다.
# 크롤링 연습사이트 01-3 페이지입니다.
# 크롤링 연습사이트 01-4 페이지입니다.

# %% [markdown]
# # CSS 셀렉터

# %%
import requests
from bs4 import BeautifulSoup
URL = "https://scrapying-study.firebaseapp.com/02/"
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")
print(soup)
# soup.select_one(셀렉터) # 셀렉터에 일치하는 하나의 태그만
# soup.select(셀렉터) # 셀렉터에 일자하는 모든 태그
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <link href="mystyle.css" rel="stylesheet" type="text/css"/>
# <title>크롤링 연습사이트 02</title>
# </head>
# <body>
# <div class="bold blue" id="title">
#         안녕하세요
#     </div>
# <div class="bold" id="content">
# <ul>
# <li>첫번쨰리스트</li>
# <li class="blue">두번째리스트</li>
# <li class="blue">세번째리스트</li>
# <li>네번째리스트</li>
# </ul>
# </div>
# <div id="winter">
# <p>온세상이 떨릴듯</p>
# <p class="blue">두근거리고 <span>익숙한 듯 편안해</span></p>
# <div>
# <p>네가 느껴져</p>
# <p class="blue">오래된 친구같아</p>
# <span>안녕하세요!</span>
# </div>
# </div>
# <a href="http://naver.com" target="_blank">네이버</a>
# <a href="http://daum.net" target="_self">다음</a>
# <a href="http://google.com" target="_self">구글</a>
# </body>
# </html>

# %% [markdown]
# ### ID 셀렉터(ID 속성을 활용) - #title

# %%
# id="title" 인것 가져옴
print(soup.select("#title"))
print()
print(soup.select_one("#title"))
# Out:
# [<div class="bold blue" id="title">
#         안녕하세요
#     </div>]
#
# <div class="bold blue" id="title">
#         안녕하세요
#     </div>

# %% [markdown]
# ### 태그 셀렉터(HTML 태그를 활용) - p, h1, h2

# %%
# id="title" 인것 가져옴
print(soup.select("title"))
print()
print(soup.select_one("title"))
# Out:
# [<title>크롤링 연습사이트 02</title>]
#
# <title>크롤링 연습사이트 02</title>

# %% [markdown]
# ### class 셀렉터(class 속성을 활용) - .content

# %%
print(soup.select(".bold")) # 2개
print()
print(soup.select(".bold.blue")) # 1개
print()
print(soup.select_one(".bold"))
# Out:
# [<div class="bold blue" id="title">
#         안녕하세요
#     </div>, <div class="bold" id="content">
# <ul>
# <li>첫번쨰리스트</li>
# <li class="blue">두번째리스트</li>
# <li class="blue">세번째리스트</li>
# <li>네번째리스트</li>
# </ul>
# </div>]
#
# [<div class="bold blue" id="title">
#         안녕하세요
#     </div>]
#
# <div class="bold blue" id="title">
#         안녕하세요
#     </div>

# %% [markdown]
# ### 속성 셀렉터(태그내 속성을 활용) -a[href], a[target="_blank"]
# - 셀렉터[어트리뷰트~="값"] - 해당 단어를 포함
# - 셀렉터[어트리뷰트^="값"] - 해당 값으로 시작
# - 셀렉터[어트리뷰트$="값"] - 해당 값으로 끝나는
# - 셀렉터[어트리뷰트*="값"] - 해당 값을 포함하는

# %%
print(soup.select('a[target="_blank"]'))
print()
print(soup.select('a[href]'))
print()
print(soup.select('a[href$=".com"]'))
# Out:
# [<a href="http://naver.com" target="_blank">네이버</a>]
#
# [<a href="http://naver.com" target="_blank">네이버</a>, <a href="http://daum.net" target="_self">다음</a>, <a href="http://google.com" target="_self">구글</a>]
#
# [<a href="http://naver.com" target="_blank">네이버</a>, <a href="http://google.com" target="_self">구글</a>]

# %% [markdown]
# ## 후손셀렉터(해당 태그 내에 포함되는 태그) - div p

# %%
print(soup.select('div#winter p'))
# Out:
# [<p>온세상이 떨릴듯</p>, <p class="blue">두근거리고 <span>익숙한 듯 편안해</span></p>, <p>네가 느껴져</p>, <p class="blue">오래된 친구같아</p>]

# %% [markdown]
# ## 자식셀렉터(해당 태그 바로 안에 포함되는 태그) -div > p

# %%
print(soup.select('div#winter > p'))
# Out:
# [<p>온세상이 떨릴듯</p>, <p class="blue">두근거리고 <span>익숙한 듯 편안해</span></p>]

# %% [markdown]
# # 실습 01
# - 사이트내에 인기검색 종목과 주요해외지수를 각각 크롤링하여 종목명과 주가지수를 아래와 같이 리스트로 정리해주세요

# %%
import requests
from bs4 import BeautifulSoup
URL = "https://scrapying-study.firebaseapp.com/03/"
response = requests.get(URL)
soup = BeautifulSoup(response.text, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <link href="mystyle.css" rel="stylesheet" type="text/css"/>
# <title>크롤링 연습사이트 03</title>
# </head>
# <body>
# <div class="title">
#         인기검색종목
#     </div>
# <ul class="lst_pop" id="popularItemList">
# <li class="up"><em>1.</em><a href="https://finance.naver.com/item/main.nhn?code=004770">써니전자</a><span>5,000</span><img alt="상한" height="11" src="https://ssl.pstatic.net/static/nfinance/ico_up2.gif" width="7"/></li>
# <li class="dn"><em>2.</em><a href="https://finance.naver.com/item/main.nhn?code=005930">삼성전자</a><span>55,200</span><img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/></li>
# <li class="up"><em>3.</em><a href="https://finance.naver.com/item/main.nhn?code=053800">안랩</a><span>81,000</span><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/></li>
# <li class="up"><em>4.</em><a href="https://finance.naver.com/item/main.nhn?code=032500">케이엠더블..</a><span>57,300</span><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/></li>
# <li class="up"><em>5.</em><a href="https://finance.naver.com/item/main.nhn?code=062970">피피아이</a><span>12,600</span><img alt="상한" height="11" src="https://ssl.pstatic.net/static/nfinance/ico_up2.gif" width="7"/></li>
# <li class="dn"><em>6.</em><a href="https://finance.naver.com/item/main.nhn?code=033780">KT&amp;G</a><span>92,500</span><img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/></li>
# <li class="up"><em>7.</em><a href="https://finance.naver.com/item/main.nhn?code=005935">삼성전자우</a><span>45,600</span><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/></li>
# <li class="dn"><em>8.</em><a href="https://finance.naver.com/item/main.nhn?code=009190">대양금속</a><span>10,550</span><img alt="하한" height="11" src="https://ssl.pstatic.net/static/nfinance/ico_down2.gif" width="7"/></li>
# <li class="up"><em>9.</em><a href="https://finance.naver.com/item/main.nhn?code=000660">SK하이닉스</a><span>94,700</span><img alt="상승" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_up.gif" width="7"/></li>
# <li class="dn"><em>10.</em><a href="https://finance.naver.com/item/main.nhn?code=017670">SK텔레콤</a><span>234,000</span><img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/></li>
# </ul>
# <div class="title">
#         주요해외지수
#     </div>
# <ul class="lst_major">
# <li class="up"><a href="https://finance.naver.com/world/sise.nhn?symbol=DJI@DJI&amp;fdtc=0">다우산업</a><span>28,647.43</span><img alt="상한" height="11" src="https://ssl.pstatic.net/static/nfinance/ico_up2.gif" width="7"/></li>
# <li class="up"><a href="https://finance.naver.com/world/sise.nhn?symbol=NAS@IXIC&amp;fdtc=0">나스닥</a><span>9,015.03</span><img alt="상한" height="11" src="https://ssl.pstatic.net/static/nfinance/ico_up2.gif" width="7"/></li>
# <li class="up"><a href="https://finance.naver.com/world/sise.nhn?symbol=HSI@HSCE&amp;fdtc=0">홍콩H</a><span>11,320.56</span><img alt="상한" height="11" src="https://ssl.pstatic.net/static/nfinance/ico_up2.gif" width="7"/></li>
# <li class="up"><a href="https://finance.naver.com/world/sise.nhn?symbol=SHS@000001&amp;fdtc=0">상해종합</a><span>3,085.20</span><img alt="상한" height="11" src="https://ssl.pstatic.net/static/nfinance/ico_up2.gif" width="7"/></li>
# <li class="dn"><a href="https://finance.naver.com/world/sise.nhn?symbol=NII@NI225&amp;fdtc=0">니케이225</a><span>23,656.62</span><img alt="하락" height="6" src="https://ssl.pstatic.net/static/nfinance/ico_down.gif" width="7"/></li>
# </ul>
# <div class="title">
#         분양중
#     </div>
# <ul class="sale_list _sale_list">
# <li class="sale_item">
# <div class="sale_box">
# <div class="sale_tit">
# <a href="#" target="_blank">H하우스장위</a>
# </div>
# <div class="sale_desc">
# <img alt="" class="thumb_img" height="82" src="https://search.pstatic.net/common/?src=https%3A%2F%2Flandthumb-phinf.pstatic.net%2F20200102_216%2Fisale_complex_1577947561833Uclja_JPEG%2Fuploadfile_202001025582218.jpg%3Ftype%3Dm232&amp;type=f82_82_q75" width="82"/>
# </div>
# <div class="sale_detail">
# <dl class="detail_info">
# <dt class="tit">보증금</dt><dd class="txt"><strong class="point">16,000</strong> 만원</dd>
# <dt class="tit">유형</dt><dd class="txt">아파트<span class="bar">|</span>일반민간임대</dd>
# <dt class="tit">규모/면적</dt><dd class="txt">분양 134세대<span class="bar">|</span>45㎡~65㎡</dd>
# <dt class="tit">위치</dt> <dd class="txt">서울시 성북구 장위동</dd>
# </dl>
# </div>
# </div>
# </li>
# <li class="sale_item">
# <div class="sale_box">
# <div class="sale_tit">
# <a href="#" target="_blank">고덕리엔파크2단지 장기전세</a>
# </div>
# <div class="sale_desc">
# <img alt="" class="thumb_img" height="82" src="https://search.pstatic.net/common/?src=https%3A%2F%2Flandthumb-phinf.pstatic.net%2F20110810_136%2Fisale_complex_1312968580369Yxsk9_JPEG%2Fuploadfile_201103075773845.jpg%3Ftype%3Dm232&amp;type=f82_82_q75" width="82"/>
# </div>
# <div class="sale_detail">
# <dl class="detail_info">
# <dt class="tit">보증금</dt><dd class="txt"><strong class="point">38,400</strong> 만원</dd>
# <dt class="tit">유형</dt><dd class="txt">아파트<span class="bar">|</span>장기전세주택</dd>
# <dt class="tit">규모/면적</dt><dd class="txt">분양 1세대<span class="bar">|</span>149㎡</dd>
# <dt class="tit">위치</dt> <dd class="txt">서울시 강동구 강일동</dd>
# </dl>
# </div>
# </div>
# </li>
# <li class="sale_item">
# <div class="sale_box">
# <div class="sale_tit">
# <a href="#" target="_blank">신정이펜하우스3단지 장기전세</a>
# </div>
# <div class="sale_desc">
# <img alt="" class="thumb_img" height="82" src="https://search.pstatic.net/common/?src=https%3A%2F%2Flandthumb-phinf.pstatic.net%2F20110810_260%2Fisale_complex_1312968335794i6pKe_JPEG%2Fuploadfile_201102243825127.jpg%3Ftype%3Dm232&amp;type=f82_82_q75" width="82"/>
# </div>
# <div class="sale_detail">
# <dl class="detail_info">
# <dt class="tit">보증금</dt><dd class="txt"><strong class="point">39,040</strong> 만원</dd>
# <dt class="tit">유형</dt><dd class="txt">아파트<span class="bar">|</span>장기전세주택</dd>
# <dt class="tit">규모/면적</dt><dd class="txt">분양 1세대<span class="bar">|</span>148㎡</dd>
# <dt class="tit">위치</dt> <dd class="txt">서울시 양천구 신정동</dd>
# </dl>
# </div>
# </div>
# </li>
# <li class="sale_item">
# <div class="sale_box">
# <div class="sale_tit">
# <a href="#" target="_blank">천왕이펜하우스2단지 장기전세</a>
# </div>
# <div class="sale_desc">
# <img alt="" class="thumb_img" height="82" src="https://search.pstatic.net/common/?src=https%3A%2F%2Flandthumb-phinf.pstatic.net%2F20110810_35%2Fisale_complex_1312968350479SO2pI_JPEG%2Fuploadfile_201102244996257.jpg%3Ftype%3Dm232&amp;type=f82_82_q75" width="82"/>
# </div>
# <div class="sale_detail">
# <dl class="detail_info">
# <dt class="tit">보증금</dt><dd class="txt"><strong class="point">38,240</strong> 만원</dd>
# <dt class="tit">유형</dt><dd class="txt">아파트<span class="bar">|</span>장기전세주택</dd>
# <dt class="tit">규모/면적</dt><dd class="txt">분양 1세대<span class="bar">|</span>142㎡</dd>
# <dt class="tit">위치</dt> <dd class="txt">서울시 구로구 오류동</dd>
# </dl>
# </div>
# </div>
# </li>
# <li class="sale_item">
# <div class="sale_box">
# <div class="sale_tit">
# <a href="#" target="_blank">송파파크데일2단지 장기전세</a>
# </div>
# <div class="sale_desc">
# <img alt="" class="thumb_img" height="82" src="https://search.pstatic.net/common/?src=https%3A%2F%2Flandthumb-phinf.pstatic.net%2F20110810_211%2Fisale_complex_1312968571650Iusoz_JPEG%2Fuploadfile_201103074989552.jpg%3Ftype%3Dm232&amp;type=f82_82_q75" width="82"/>
# </div>
# <div class="sale_detail">
# <dl class="detail_info">
# <dt class="tit">보증금</dt><dd class="txt"><strong class="point">45,600</strong> 만원</dd>
# <dt class="tit">유형</dt><dd class="txt">아파트<span class="bar">|</span>장기전세주택</dd>
# <dt class="tit">규모/면적</dt><dd class="txt">분양 1세대<span class="bar">|</span>150㎡</dd>
# <dt class="tit">위치</dt> <dd class="txt">서울시 송파구 마천동</dd>
# </dl>
# </div>
# </div>
# </li>
# </ul></body>
# </html>

# %%
popularItem_list = []
lst_major = []
popularItem_result = soup.select('ul#popularItemList > li')
lst_major_result = soup.select('ul.lst_major > li')

for i in popularItem_result:
    popularItem_list.append([i.select('a')[0].text,i.select('span')[0].text])


for i in lst_major_result:
    lst_major.append([i.select('a')[0].text,i.select('span')[0].text])
print(popularItem_list)
print(lst_major)
# Out:
# [['써니전자', '5,000'], ['삼성전자', '55,200'], ['안랩', '81,000'], ['케이엠더블..', '57,300'], ['피피아이', '12,600'], ['KT&G', '92,500'], ['삼성전자우', '45,600'], ['대양금속', '10,550'], ['SK하이닉스', '94,700'], ['SK텔레콤', '234,000']]
# [['다우산업', '28,647.43'], ['나스닥', '9,015.03'], ['홍콩H', '11,320.56'], ['상해종합', '3,085.20'], ['니케이225', '23,656.62']]

# %%
up_down_p = []
up_down_m = []
for i in popularItem_result:
    up_down_p.append([i.select('a')[0].text, i.select('img')[0]['alt']])    


for i in lst_major_result:
    up_down_m.append([i.select('a')[0].text,i.select('img')[0]['alt']])
print(up_down_p)
print(up_down_m)
# Out:
# [['써니전자', '상한'], ['삼성전자', '하락'], ['안랩', '상승'], ['케이엠더블..', '상승'], ['피피아이', '상한'], ['KT&G', '하락'], ['삼성전자우', '상승'], ['대양금속', '하한'], ['SK하이닉스', '상승'], ['SK텔레콤', '하락']]
# [['다우산업', '상한'], ['나스닥', '상한'], ['홍콩H', '상한'], ['상해종합', '상한'], ['니케이225', '하락']]

# %%
up_down_p_2 = []
up_down_m_2 = []
up_list = ['상한', '상승']
for i in popularItem_result:
    if i.select('img')[0]['alt'] in up_list:
        up_down_p_2.append([i.select('a')[0].text, i.select('span')[0].text])


for i in lst_major_result:
    if i.select('img')[0]['alt'] in up_list:
        up_down_m_2.append([i.select('a')[0].text, i.select('span')[0].text])
print(up_down_p_2)
print(up_down_m_2)
# Out:
# [['써니전자', '5,000'], ['안랩', '81,000'], ['케이엠더블..', '57,300'], ['피피아이', '12,600'], ['삼성전자우', '45,600'], ['SK하이닉스', '94,700']]
# [['다우산업', '28,647.43'], ['나스닥', '9,015.03'], ['홍콩H', '11,320.56'], ['상해종합', '3,085.20']]

# %%
answer = []

for i in soup.select("div.sale_box"):
    answer.append({'이름':i.select_one('a').text, '분양가':re.sub(",*( 만원)*","",i.select('dd')[0].text), 
                 '유형':i.select('dd')[1].text.split('|')[0], '분양유형':i.select('dd')[1].text.split('|')[1]
                 , '세대수':i.select('dd')[2].text.split('|')[0], '평형':i.select('dd')[2].text.split('|')[1]})
print(answer)
# Out:
# [{'이름': 'H하우스장위', '분양가': '16000', '유형': '아파트', '분양유형': '일반민간임대', '세대수': '분양 134세대', '평형': '45㎡~65㎡'}, {'이름': '고덕리엔파크2단지 장기전세', '분양가': '38400', '유형': '아파트', '분양유형': '장기전세주택', '세대수': '분양 1세대', '평형': '149㎡'}, {'이름': '신정이펜하우스3단지 장기전세', '분양가': '39040', '유형': '아파트', '분양유형': '장기전세주택', '세대수': '분양 1세대', '평형': '148㎡'}, {'이름': '천왕이펜하우스2단지 장기전세', '분양가': '38240', '유형': '아파트', '분양유형': '장기전세주택', '세대수': '분양 1세대', '평형': '142㎡'}, {'이름': '송파파크데일2단지 장기전세', '분양가': '45600', '유형': '아파트', '분양유형': '장기전세주택', '세대수': '분양 1세대', '평형': '150㎡'}]
